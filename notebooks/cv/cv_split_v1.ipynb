# %% [markdown]
# # CV Split Search (v1)

# %%
# -------------------------
# 0) Config
# -------------------------
import os

CSIRO_CODE_DIR = "/notebooks/CSIRO"
DATA_ROOT = "/notebooks/kaggle/csiro"
TRAIN_CSV = f"{DATA_ROOT}/train.csv"

N_TRIALS = 300
TOP_K = 10
SEED_START = 0
N_SPLITS = 5

# Constraints / scoring
MIN_FOLD_N = None          # None = auto
MIN_TARGET_VAR = 1e-3
MIN_STATES_PER_FOLD = None
MIN_SEASONS_PER_FOLD = 2
N_BINS = 4
MIN_BIN_N = 5

GROUP_MODE = "state_quarter"  # "state_quarter" or "date"
DATE_COL = "Sampling_Date"
STATE_COL = "State"

OUT_PATH = "/notebooks/cv/cv_split_search_v1.csv"

# Guard rails
for name, val in {
    "CSIRO_CODE_DIR": CSIRO_CODE_DIR,
    "TRAIN_CSV": TRAIN_CSV,
}.items():
    if val is None:
        raise ValueError(f"{name} is None; set it before running.")

# %%
# -------------------------
# 1) Imports
# -------------------------
import sys
import pandas as pd

sys.path.insert(0, CSIRO_CODE_DIR)

from csiro.data import load_train_wide
from csiro.utils_v2 import search_cv_splits

# %%
# -------------------------
# 2) Load data
# -------------------------
wide_df = load_train_wide(TRAIN_CSV, root=DATA_ROOT)
print("rows", len(wide_df))
# Out:
# rows 357

# %%
# -------------------------
# 3) Run search
# -------------------------
results = search_cv_splits(
    wide_df,
    n_splits=N_SPLITS,
    n_trials=N_TRIALS,
    seed_start=SEED_START,
    top_k=TOP_K,
    group_mode=GROUP_MODE,
    date_col=DATE_COL,
    state_col=STATE_COL,
    min_fold_n=MIN_FOLD_N,
    min_target_var=MIN_TARGET_VAR,
    min_states_per_fold=MIN_STATES_PER_FOLD,
    min_seasons_per_fold=MIN_SEASONS_PER_FOLD,
    n_bins=N_BINS,
    min_bin_n=MIN_BIN_N,
)

print("found", len(results), "candidates")
results[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # -------------------------
#       2 # 3) Run search
#       3 # -------------------------
# ----> 4 results = search_cv_splits(
#       5     wide_df,
#       6     n_splits=N_SPLITS,
#       7     n_trials=N_TRIALS,
#       8     seed_start=SEED_START,
#       9     top_k=TOP_K,
#      10     group_mode=GROUP_MODE,
#      11     date_col=DATE_COL,
#      12     state_col=STATE_COL,
#      13     min_fold_n=MIN_FOLD_N,
#      14     min_target_var=MIN_TARGET_VAR,
#      15     min_states_per_fold=MIN_STATES_PER_FOLD,
#      16     min_seasons_per_fold=MIN_SEASONS_PER_FOLD,
#      17     n_bins=N_BINS,
#      18     min_bin_n=MIN_BIN_N,
#      19 )
#      21 print("found", len(results), "candidates")
#      22 results[:3]
#
# File /notebooks/CSIRO/csiro/utils_v2.py:261, in search_cv_splits(wide_df, n_splits, n_trials, seed_start, top_k, group_mode, date_col, state_col, targets, min_fold_n, min_target_var, min_states_per_fold, min_seasons_per_fold, n_bins, min_bin_n)
#     259     targets = list(DEFAULTS.get("targets", [])) or []
#     260 if not targets:
# --> 261     targets = list(wide_df.columns.intersection(TARGETS))
#     263 if min_fold_n is None:
#     264     min_fold_n = max(20, int(len(wide_df) / max(int(n_splits), 1) * 0.6))
#
# NameError: name 'TARGETS' is not defined

# %%
# -------------------------
# 4) Save top-K
# -------------------------
import os
import pandas as pd

os.makedirs(os.path.dirname(OUT_PATH), exist_ok=True)

if results:
    df_out = pd.DataFrame(results)
    df_out.to_csv(OUT_PATH, index=False)
    print("Wrote", OUT_PATH)
else:
    print("No candidates found; relax constraints.")
