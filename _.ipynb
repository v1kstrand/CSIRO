# %%
import CSIRO

# %%
CSIRO.__dict__
# Out:
# {'__name__': 'CSIRO',
#  '__doc__': None,
#  '__package__': 'CSIRO',
#  '__loader__': <_frozen_importlib_external._NamespaceLoader at 0x7f16f64bf070>,
#  '__spec__': ModuleSpec(name='CSIRO', loader=<_frozen_importlib_external._NamespaceLoader object at 0x7f16f64bf070>, submodule_search_locations=_NamespacePath(['/notebooks/CSIRO'])),
#  '__file__': None,
#  '__path__': _NamespacePath(['/notebooks/CSIRO'])}
