# %%
import sys
sys.path.insert(0, "/notebooks/CSIRO")
from csiro.scripts.train_cv_func import train_cv

# %%
train_cv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_cv()
#
# TypeError: train_cv() missing 3 required keyword-only arguments: 'csv', 'dino_repo', and 'dino_weights'
