# %%
os.getenv("COMET_API_KEY")

# %%
import comet_ml, os
comet_exp = comet_ml.start(
    api_key=os.getenv("COMET_API_KEY"),
    project_name="test",
    experiment_key=None,
)
# Out:
# COMET ERROR: Failed to create Comet experiment, reason: ValueError('Comet.ml requires an API key. Please provide as the first argument to Experiment(api_key) or as an environment variable named COMET_API_KEY ')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import comet_ml, os
# ----> 2 comet_exp = comet_ml.start(
#       3     api_key=os.getenv("COMET_API_KEY"),
#       4     project_name="test",
#       5     experiment_key=None,
#       6 )
#
# File /notebooks/venvs/pt27cu118/lib/python3.10/site-packages/comet_ml/comet_start/comet_start.py:94, in start(api_key, workspace, project, project_name, experiment_key, mode, online, source, experiment_config)
#      92 except Exception as e:
#      93     LOGGER.error(COMET_START_FAILED_TO_CREATE_EXPERIMENT_ERROR, e, exc_info=True)
# ---> 94     raise e
#
# ...

# %%
import sys
sys.path.insert(0, "/notebooks/CSIRO")
from csiro.scripts.train_cv_func import train_cv
train_cv()
# Out:
# COMET ERROR: Failed to create Comet experiment, reason: ValueError('Comet.ml requires an API key. Please provide as the first argument to Experiment(api_key) or as an environment variable named COMET_API_KEY ')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /notebooks/CSIRO/csiro/train.py:280, in run_groupkfold_cv(dataset, wide_df, n_splits, seed, group_col, stratify_col, train_tfms_fn, post_tfms_fn, tfms_fn, comet_exp_name, sweep_config, **train_kwargs)
#     278     import comet_ml  # type: ignore
# --> 280     comet_exp = comet_ml.start(
#     281         api_key=os.getenv("COMET_API_KEY"),
#     282         project_name=comet_exp_name,
#     283         experiment_key=None,
#     284     )
#     285 except Exception as e:
#
# ...
